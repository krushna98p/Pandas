# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris=pd.read_csv('iris.csv')
iris.head()
iris['Species'].sample(5)
# Out:
# 54     Iris-versicolor
# 149     Iris-virginica
# 93     Iris-versicolor
# 105     Iris-virginica
# 24         Iris-setosa
# Name: Species, dtype: object

# %%
iris['Species'].sample(5)
iris['Species']=iris['Species'].replace({'Iris-setosa':0,'Iris-versicolor':1,'Iris-virginica':2})
# Out:
# C:\Users\ankit\AppData\Local\Temp\ipykernel_23920\3817106987.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   iris['Species']=iris['Species'].replace({'Iris-setosa':0,'Iris-versicolor':1,'Iris-virginica':2})

# %% [markdown]
# ### coloured scatter plot

# %%
plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'],c=iris['Species'],cmap='summer',alpha=0.5) # alpha is opacity of grapn, cmap is color
plt.xlabel('SepalLengthCm')
plt.ylabel('PetalLengthCm')
plt.colorbar()

# %%
# plot size
plt.figure(figsize=(10,10))
plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'],c=iris['Species'])
plt.xlabel('SepalLengthCm')
plt.ylabel('PetalLengthCm')
plt.colorbar()

# %% [markdown]
# ### Annotation

# %%
batter=pd.read_csv('batter.csv')
df=batter.sample(25)
df
# Out:
#                batter  runs        avg  strike_rate
# 395           JM Kemp    26  13.000000   104.000000
# 251          NK Patel   121  30.250000    97.580645
# 539        GD McGrath     4   4.000000    80.000000
# 50       Ishan Kishan  1870  29.218750   129.501385
# 488          M Jansen     9   3.000000    81.818182
# 154       Rashid Khan   313  11.178571   146.261682
# 323         JJ Bumrah    56   8.000000    82.352941
# 513         SS Shaikh     6   6.000000    85.714286
# 440      JR Hazlewood    18        NaN    66.666667
# 133         LR Shukla   405  15.000000   113.128492
# 305    Mohammed Shami    69   6.272727    93.243243
# 21            RR Pant  2851  34.768293   142.550000
# 263     SE Rutherford   106  15.142857    99.065421
# 209          AC Voges   181  45.250000   126.573427
# 473   Karanveer Singh    12  12.000000    70.588235
# 70           DJ Hooda  1237  20.278689   127.525773
# 589            AS Roy     0   0.000000     0.000000
# 316     Anirudh Singh    63  15.750000    91.304348
# 342     Yashpal Singh    47  11.750000    70.149254
# 592          L Ablish     0        NaN     0.000000
# 222          PA Reddy   164  16.400000    98.203593
# 11          AT Rayudu  4190  28.896552   124.148148
# 393        PJ Sangwan    26   3.250000    55.319149
# 572  PM Sarvesh Kumar     1        NaN    50.000000
# 239      Kamran Akmal   128  25.600000   164.102564

# %%
plt.figure(figsize=(10,10))
plt.scatter(df['avg'],df['strike_rate'],s=df['runs'])
for i in range(df.shape[0]):
    plt.text(df['avg'].values[i],df['strike_rate'].values[i],df['batter'].values[i])

# %% [markdown]
# ### Horizontal and vertical lines

# %%
plt.figure(figsize=(10,10))
plt.scatter(df['avg'],df['strike_rate'],s=df['runs'])
for i in range(df.shape[0]):
    plt.text(df['avg'].values[i],df['strike_rate'].values[i],df['batter'].values[i])
plt.axhline(130, color='red')
plt.axvline(30,color='red')

# %% [markdown]
# ### subplot

# %%
# a diss way to plot graph
plt.scatter(batter['avg'],batter['strike_rate'])

# %%
# 2nd way
fig , ax = plt.subplots(figsize=(10,10))
ax.scatter(batter['avg'],batter['strike_rate'])
ax.set_title('avg vs strike rate')
ax.set_xlabel('avg')
fig.show()
# Out:
# C:\Users\ankit\AppData\Local\Temp\ipykernel_23920\2044914707.py:6: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
# 2 sise by side graph
fig ,ax =plt.subplots(nrows=2,ncols=1,sharex=True)
ax[0].scatter(batter['avg'],batter['strike_rate'])
ax[1].scatter(batter['avg'],batter['runs'])
ax[0].set_title('avg vs stike rate')
ax[1].set_title('avg vs runs')
ax[1].set_xlabel('avg')
ax[0].set_ylabel('strike rate')
ax[1].set_ylabel('runs')
# Out:
# Text(0, 0.5, 'runs')

# %%
fig ,ax =plt.subplots(nrows=2,ncols=2,figsize=(10,10))
ax[0,0].scatter(batter['avg'],batter['strike_rate'])
ax[0,1].scatter(batter['avg'],batter['runs'])
ax[1,0].hist(batter['avg'])
ax[1,1].hist(batter['strike_rate'])

ax[0,0].set_title('avg vs stike rate')
ax[0,1].set_title('avg vs runs')
ax[0,1].set_xlabel('avg')
ax[0,0].set_ylabel('strike rate')
ax[0,1].set_ylabel('runs')
ax[1,0].set_title('avg hist')
ax[1,1].set_title('strike rates hist')
# Out:
# Text(0.5, 1.0, 'strike rates hist')

# %%
# 2nd way
fig =plt.figure()
ax1=fig.add_subplot(221)
ax1.scatter(batter['avg'],batter['strike_rate'])
ax2=fig.add_subplot(222)
ax2.scatter(batter['avg'],batter['runs'])
ax3=fig.add_subplot(223)
ax3.hist(batter['avg'])
ax4=fig.add_subplot(224)
ax4.hist(batter['strike_rate'])
fig.show()
# Out:
# C:\Users\ankit\AppData\Local\Temp\ipykernel_23920\1366965540.py:11: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# ### 3D scatter plots

# %%
batter
# Out:
#              batter  runs        avg  strike_rate
# 0           V Kohli  6634  36.251366   125.977972
# 1          S Dhawan  6244  34.882682   122.840842
# 2         DA Warner  5883  41.429577   136.401577
# 3         RG Sharma  5881  30.314433   126.964594
# 4          SK Raina  5536  32.374269   132.535312
# ..              ...   ...        ...          ...
# 600         C Nanda     0   0.000000     0.000000
# 601      Akash Deep     0   0.000000     0.000000
# 602         S Ladda     0   0.000000     0.000000
# 603  V Pratap Singh     0   0.000000     0.000000
# 604    S Lamichhane     0   0.000000     0.000000
#
# [605 rows x 4 columns]

# %%
fig=plt.figure()
ax=plt.subplot(projection='3d')
ax.scatter(batter['runs'],batter['avg'],batter['strike_rate'])
