# %% [markdown]
# ### why Saborn ?

# %% [markdown]
# - provid a layer of abstraction hence simpler to use
# - better aesthetics
# - more grapn include

# %% [markdown]
# #### Seaborn Roadmap
#
# types of functions
# - Figure Level
# - Axis level
#
# Main Classification
#
# - Relational plot
# - Distribution plot
# - Categorical plot
# - Regression plot
# - Matrix plot
# - Multiplot

# %% [markdown]
# 1. Relational Plot
# - to see the statestical relation between 2 or more variable
# -Bivariate Analysis
# Plots
# - scatter plot
# - line plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
tips=sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# scatter plot => axes level function (hue it change catagories)
sns.scatterplot(data=tips,x='total_bill',y='tip',hue='sex',style='time',size='size')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# replot => figure level function =>squre shape
sns.relplot(data=tips,x='total_bill',y='tip',kind='scatter',hue='sex',style='time',size='size')

# %%
# line plot
gap=px.data.gapminder()
temp=gap[gap['country']=='India']
temp
# Out:
#     country continent  year  lifeExp         pop    gdpPercap iso_alpha  \
# 696   India      Asia  1952   37.373   372000000   546.565749       IND
# 697   India      Asia  1957   40.249   409000000   590.061996       IND
# 698   India      Asia  1962   43.605   454000000   658.347151       IND
# 699   India      Asia  1967   47.193   506000000   700.770611       IND
# 700   India      Asia  1972   50.651   567000000   724.032527       IND
# 701   India      Asia  1977   54.208   634000000   813.337323       IND
# 702   India      Asia  1982   56.596   708000000   855.723538       IND
# 703   India      Asia  1987   58.553   788000000   976.512676       IND
# 704   India      Asia  1992   60.223   872000000  1164.406809       IND
# 705   India      Asia  1997   61.765   959000000  1458.817442       IND
# 706   India      Asia  2002   62.879  1034172547  1746.769454       IND
# 707   India      Asia  2007   64.698  1110396331  2452.210407       IND
#
#      iso_num
# 696      356
# ...

# %%
# axes level function
sns.lineplot(data=temp,x='year',y='lifeExp')
# Out:
# <Axes: xlabel='year', ylabel='lifeExp'>

# %%
#using relplot
sns.relplot(data=temp,x='year',y='lifeExp',kind='line')

# %%
temp1=gap[gap['country'].isin(['India','Brazil','Germany','China'])]
temp1
# Out:
#      country continent  year   lifeExp         pop     gdpPercap iso_alpha  \
# 168   Brazil  Americas  1952  50.91700    56602560   2108.944355       BRA
# 169   Brazil  Americas  1957  53.28500    65551171   2487.365989       BRA
# 170   Brazil  Americas  1962  55.66500    76039390   3336.585802       BRA
# 171   Brazil  Americas  1967  57.63200    88049823   3429.864357       BRA
# 172   Brazil  Americas  1972  59.50400   100840058   4985.711467       BRA
# 173   Brazil  Americas  1977  61.48900   114313951   6660.118654       BRA
# 174   Brazil  Americas  1982  63.33600   128962939   7030.835878       BRA
# 175   Brazil  Americas  1987  65.20500   142938076   7807.095818       BRA
# 176   Brazil  Americas  1992  67.05700   155975974   6950.283021       BRA
# 177   Brazil  Americas  1997  69.38800   168546719   7957.980824       BRA
# 178   Brazil  Americas  2002  71.00600   179914212   8131.212843       BRA
# ...

# %%
sns.relplot(data=temp1,x='year',y='lifeExp',kind='line',hue='country',style='continent')

# %%
# facet plot => only work with figure level plot
sns.relplot(kind='scatter',data=tips,x='total_bill',y='tip',col='sex',row='smoker')

# %%
# col wrap
sns.relplot(data=gap,x='lifeExp',y='gdpPercap',kind='scatter',col='year',col_wrap=4)

# %% [markdown]
# 2. Distribution Plot
# - used for univariate analysis
# - used to find out the distribution
# - range of the observation
# - central tendancy
# - is the data bimodel?
# - are there outliers?
#
# Plots
# - Histogram
# - kdeplot
# - rugplot

# %%
# figure level function -> diskplot
# axes level -> histplot, kdeplot,rugplot

# %%
# plotting univariate histogram
sns.histplot(data=tips,x='total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.displot(data=tips,x='total_bill')

# %%
# bins
sns.displot(data=tips,x='total_bill',bins=10)

# %%
# it's also possible to visualize the distribution of a categorical variable usinf the logic of a histogram
# Discrete bins are automatically set for categot=rical variable

#like count plot
sns.displot(data=tips,x='day',hue='time',element='step')

# %%
titanic=sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.displot(data=titanic,x='age',hue='sex',element='step')

# %%
sns.displot(data=titanic,x='age',col='sex')

# %%
# kdeplot
# rather than using discrete bins , a KDE plot smoots the observation with a gaussion kernel, producing a continous density estimates
sns.kdeplot(data=tips,x='total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.displot(kind='kde',data=tips,x='total_bill',hue='sex',fill='True')

# %%
# in figure level function we cant change  size by matplotlib
# it change by passing hight and aspecct for manage with ratio
sns.displot(kind='kde',data=tips,x='total_bill',hue='sex',fill='True',height=10,aspect=1)

# %%
# rug plot
# plot marginal distribution by drawing tricks along the x and y axes

# this function is intended to complete other plotsby showing the location of individual observation in an unbrusive way.
sns.kdeplot(data=tips,x='total_bill')
sns.rugplot(data=tips,x='total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
# Bivariate histogram
# a bivariate histogram bins the data within rectangle that tile the plot
# and then show the count of obeservation within each rectangle with the fill order
#sns.histplot(data=tips,x='total_bill',y='tip')
sns.displot(data=tips,x='total_bill',y='tip',kind='hist')

# %%
# Bivariate Kdeplot
# a bivariate Kdeplot smooths the (x,y) observation with a 2D Gausian
sns.displot(data=tips,x='total_bill',y='tip',kind='kde')

# %% [markdown]
# 4. Matrix Plot
#
#
# plots
# - heatmap
# - clustermap

# %%
# heatmap
# plot rectangular data as a color encoded matrix
h=gap.pivot(index='country',columns='year',values='lifeExp')
# axes level function (it does not have figure finction)
plt.figure(figsize=(15,15))
sns.heatmap(h)
# Out:
# <Axes: xlabel='year', ylabel='country'>

# %%
plt.figure(figsize=(15,15))
eu=gap[gap['continent']=='Europe'].pivot(index='country',columns='year',values='lifeExp')
sns.heatmap(eu,annot=True,linewidths=0.5,cmap='viridis')
# annot shares values & linewidth create gap between boxes
# Out:
# <Axes: xlabel='year', ylabel='country'>

# %%
# clustermap
# plot  a matrix dataset as a hierarchical- clustered heatmap
# this function requires scipy to be available.
iris=px.data.iris()
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      species_id
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ..          ...
# ...

# %%
sns.clustermap(iris.iloc[:,[0,1,2,3]])

# %% [markdown]
# ### Categorical Plot
# #### categorical scatter plot
# - stripplot
# - swarmplot
#
# #### categorical Distribution plots
# - Boxplot
# - violinplot
#
# #### Categorical Estimate plot -> for central tendancy
#
# - barplot
# - pointplot
# - countplot
#
# #### Figure level function => catplot

# %%
# strip plot
# axes function
sns.stripplot(data=tips,x='day',y='total_bill')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.catplot(data=tips,x='day',y='total_bill',kind='strip',hue='sex')

# %%
# jitter
sns.catplot(data=tips,x='day',y='total_bill',kind='strip',hue='sex',jitter=0.3)

# %%
# swarmplot
#sns.swarmplot(data=tips,x='day',y='total_bill')
sns.catplot(kind='swarm',data=tips,x='day',y='total_bill',hue='sex')

# %% [markdown]
# ### boxplot
#
# A boxplot is a standardized way of displaying the distribution of data on a five number summary("minimum",first quartile[Q1],median,third quartile[Q3] and "maximum"). It can tell about your outliers and what their values are. Boxplots can also tell you if your data is symmetrical, how tightly your data is grouped and if and how ypur daata is skewed.
#
#
#
# ![image.png](data:image/png;base64,...)

# %%
# boxplot
#sns.boxplot(data=tips,x='day',y='total_bill')
sns.catplot(kind='box',data=tips,x='day',y='total_bill',hue='sex')

# %%
# single boxplot -> numerical  col
sns.boxplot(data=tips,y='total_bill')
# Out:
# <Axes: ylabel='total_bill'>

# %% [markdown]
# ### violinplot = (Boxplot + KDEplot)

# %%
# violinplot
#sns.violinplot(data=tips,x='day',y='total_bill')
sns.catplot(data=tips,x='day',y='total_bill',kind='violin',hue='sex')

# %%
# split
import seaborn as sns
sns.catplot(data=tips,x='day',y='total_bill',kind='violin',hue='sex',split=True)

# %% [markdown]
# ### Barplot

# %%
# barplot
sns.barplot(data=tips,x='sex',y='total_bill')
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# When there are multiple observation in each category, it also uses bootstrapping to compute a confidence interval around the estimate,which is plotted using error bars(black bar over it)

# %%
sns.barplot(data=tips,x='sex',y='total_bill',errorbar=('ci', True))# estimator = np.mean and also we can provide any funcrion
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
# point plot
sns.pointplot(data=tips,x='sex',y='total_bill')
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# When there are multiple observation in each category, it also uses bootstrapping to compute a confidence interval around the estimate, which is plotted using error bars

# %%
sns.pointplot(data=tips,x='sex',y='total_bill',errorbar=('ci', True))# estimator = np.mean and also we can provide any funcrion
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# ### countplot
# A special case for the bar plot is when you want to show the number of observations in each category rather than computing a statistic for a second variable. this is similar to a histogram over a categorical, rather than quantitative, variable

# %%
sns.countplot(data=tips,x='sex',hue='day')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
# faceing using catplot
sns.catplot(data=tips,x='sex',y='total_bill',col='smoker',kind='bar',row='time')

# %% [markdown]
# ### Regration plot
# - regplot
# - implot<br>
# In the simple inocation , both functions draw a scatterplot of two variable, x and y ,and then fit regration medel y~x and plot the resulring regration line and a 95% confidence interval for the regression.

# %%
#sns.regplot(data=tips,x='total_bill',y='tip') hue is not availabe there
sns.lmplot(data=tips,x='total_bill',y='tip',hue='sex')

# %%
# residual plot
sns.residplot(data=tips,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### Multiplots

# %% [markdown]
# A second to plot faset plots -> FacetGrid

# %%
g=sns.FacetGrid(data=tips,col='day',row='time')
g.map(sns.boxplot,'sex','total_bill')
# Out:
# c:\Users\ankit\anaconda3\Lib\site-packages\seaborn\axisgrid.py:718: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
g=sns.FacetGrid(data=tips,col='day',row='time',hue='smoker')
g.map(sns.scatterplot,'sex','total_bill')
g.add_legend()

# %% [markdown]
# ### plotting pairwise relationship (pairgrid vs pairplot)

# %%
# pairplot
sns.pairplot(iris,hue='species')

# %%
# PairGrid
g=sns.PairGrid(data=iris,hue='species')
g.map(sns.scatterplot)

# %%
# map diag -> map offdia
g=sns.PairGrid(data=iris,hue='species')
g.map_diag(sns.histplot)
g.map_offdiag(sns.scatterplot)

# %%
# map_dig -> map_upper -> map_lower
iris=sns.load_dataset('iris')
g=sns.PairGrid(data=iris,hue='species')# in vars we can pass only columns to work only on it
g.map_diag(sns.histplot)
g.map_lower(sns.scatterplot)
g.map_upper(sns.kdeplot)

# %% [markdown]
# ### jointgrid vs jointplot

# %%
sns.jointplot(data=tips,x='total_bill',y='tip',kind='kde')

# %%
g=sns.JointGrid(data=tips,x='total_bill',y='tip')
g.plot(sns.kdeplot,sns.histplot)

# %%
# get dataset names in seaborn
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
# load dataset
sns.load_dataset('penguins')
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...
